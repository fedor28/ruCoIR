# %%
import pandas as pd

# %%
df = pd.read_csv('/home/raid_storage/fyaronsky/ruCoIR/results/results.csv')
df
# Out:
#                   Unnamed: 0  Qwen/Qwen3-Embedding-0.6B  \
# 0                      apps.                    0.82420
# 1           codefeedback-st.                    0.92171
# 2          stackoverflow-qa.                    0.91019
# 3                     cosqa.                    0.41885
# 4          CodeSearchNet-go.                    0.85627
# 5        CodeSearchNet-java.                    0.83726
# 6  CodeSearchNet-javascript.                    0.77867
# 7        CodeSearchNet-ruby.                    0.90007
# 8      CodeSearchNet-python.                    0.84108
# 9         CodeSearchNet-php.                    0.89685
#
#    Qwen/Qwen3-Embedding-4B  Qwen/Qwen3-Embedding-8B  \
# 0                  0.92906                  0.93252
# 1                  0.96204                  0.97687
# 2                  0.95474                  0.96097
# 3                  0.48151                  0.47824
# 4                  0.93391                  0.92184
# ...

# %%
# Создаем строку со средними
new_row = {'Unnamed: 0': 'Mean'}
for col in df.columns[1:]:
    new_row[col] = df[col].mean()

# Добавляем в DataFrame
df.loc[len(df)] = new_row

df
# Out:
#                    Unnamed: 0  Qwen/Qwen3-Embedding-0.6B  \
# 0                       apps.                   0.824200
# 1            codefeedback-st.                   0.921710
# 2           stackoverflow-qa.                   0.910190
# 3                      cosqa.                   0.418850
# 4           CodeSearchNet-go.                   0.856270
# 5         CodeSearchNet-java.                   0.837260
# 6   CodeSearchNet-javascript.                   0.778670
# 7         CodeSearchNet-ruby.                   0.900070
# 8       CodeSearchNet-python.                   0.841080
# 9          CodeSearchNet-php.                   0.896850
# 10                       Mean                   0.818515
#
#     Qwen/Qwen3-Embedding-4B  Qwen/Qwen3-Embedding-8B  \
# 0                  0.929060                 0.932520
# 1                  0.962040                 0.976870
# 2                  0.954740                 0.960970
# 3                  0.481510                 0.478240
# ...
